# %% [markdown]
# <a href="https://colab.research.google.com/github/Immaczx/ModeladoySimulacion/blob/main/Tarea_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np  
import matplotlib.pyplot as plt

# %%
def step_euler(y,h,f):
  next_y = y+h*f(y)
  return next_y

def euler(h, f, y_0, start_t, end_t):
  N = int((end_t - start_t)/h)
  t_list = np.linspace(start_t, end_t, N+1)
  y_list = np.zeros(N+1)
  y_list[0]=y_0

  for i in range(0,N):
    y_list[i+1] = step_euler(y_list[i], h, f)
  return t_list, y_list

# %%
def g(y):
  crecimiento = np.log(2)*y
  return crecimiento

y_0 = 1
h = 0.01
t_0 = 0
t_N = 10

t_list, y_list = euler(h, g, y_0, t_0, t_N)
plt.figure(figsize=(10,6))
plt.plot(t_list, y_list)

plt.plot(t_list, np.power(2, t_list))
plt.grid()
plt.show()

# %% [markdown]
# #Tarea
#
# $$\dot{x}=sin(x)  \quad x_0=0,x_0=\pi/4, x_0=\pi/2$$

# %%
def g(y):
  crecimiento = np.sin(y)
  return crecimiento

y_ =np.linspace(-2*np.pi,2*np.pi,25)
y_0=[0, np.pi/4, np.pi/2]
h=0.01
t_0=0
t_N=4
plt.figure(figsize=(15,6))
for y in y_ :
  t_list,y_list=euler(h,g,y, t_0,t_N)
  plt.plot(t_list,y_list)
plt.tight_layout()
plt.grid()

# %% [markdown]
# #Exercise 2.2 of Nonlinear Dynamics and Chaos by Steven H.Strogatz
# Analyze the following equations graphically. In each case, sketch the vector field on the real line, find all the fixed points, classify their stability, and sketch the graph of x ( t ) for different initial conditions. Then try for a few minutes to obtain the analytical solution for x ( t ); if you get stuck, don’t try for too long since in several cases it’s impossible to solve the equation in closed form!

# %% [markdown]
# #2.2.1 $$\dot{x}=4x^2-16 $$

# %%
def g(y):
  crecimiento = 4*y**2-16
  return crecimiento

x=np.linspace(-2.1,2.1,42)
X, Y = np.meshgrid(np.linspace(-2.5,2.5,11), 0)
U = g(X)/abs(g(X))
V = 0
fig, ax = plt.subplots(figsize=(12,5))
Q = ax.quiver(X, Y, U, V, pivot='mid', width=0.005)

plt.plot(x,g(x))
plt.tight_layout()
plt.grid()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in true_divide
#   import sys

# %%
def g(y):
  crecimiento = 4*y**2-16
  return crecimiento

y_0 =np.linspace(-2.1,2.1,42)
h=0.01
t_0=0
t_N=0.2
plt.figure(figsize=(15,6))
for y in y_0 :
  t_list,y_list=euler(h,g,y, t_0,t_N)
  plt.plot(t_list,y_list)
plt.tight_layout()
plt.grid()

# %% [markdown]
# #2.2.2 $$\dot{x}=1-x^{14} $$

# %%
def g(y):
  crecimiento = 1-y**14
  return crecimiento

x=np.linspace(-1.6,1.6,50)
X, Y = np.meshgrid(np.linspace(-1.6,1.6,15), 0)
U = g(X)/abs(g(X))
V = 0
fig, ax = plt.subplots(figsize=(12,5))
Q = ax.quiver(X, Y, U, V, pivot='mid', width=0.004)

plt.plot(x,g(x))
plt.tight_layout()
plt.grid()

# %%
def g(y):
  crecimiento = 1-y**14
  return crecimiento

y_0 =np.linspace(-1.1,1.5,27)
h=0.001
t_0=0
t_N=2.5
plt.figure(figsize=(15,6))
for y in y_0 :
  t_list,y_list=euler(h,g,y, t_0,t_N)
  plt.plot(t_list,y_list)
plt.axis([t_0,t_N,-2,2])
plt.tight_layout()
plt.grid()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in double_scalars

# %% [markdown]
# #2.2.3 $$\dot{x}=x-x^{3} $$

# %%
def g(y):
  crecimiento = y-y**3
  return crecimiento

x=np.linspace(-2,2,23)
X, Y = np.meshgrid(np.linspace(-2,2,13), 0)
U = g(X)/abs(g(X))
V = 0
fig, ax = plt.subplots(figsize=(12,5))
Q = ax.quiver(X, Y, U, V, pivot='mid', width=0.005)

plt.plot(x,g(x))
plt.tight_layout()
plt.grid()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in true_divide
#   import sys

# %%
def g(y):
  crecimiento = y-y**3
  return crecimiento

y_0 =np.linspace(-2,2,23)
h=0.01
t_0=0
t_N=3
plt.figure(figsize=(15,6))
for y in y_0 :
  t_list,y_list=euler(h,g,y, t_0,t_N)
  plt.plot(t_list,y_list)
plt.tight_layout()
plt.grid()

# %% [markdown]
# #2.2.4 $$\dot{x}=e^{-x}sin(x) $$

# %%
def g(y):
  crecimiento = (np.exp(-y))*np.sin(y)
  return crecimiento

x=np.linspace(-4,4,41)
X, Y = np.meshgrid(np.linspace(-4,4,15), 0)
U = g(X)/abs(g(X))
V = 0
fig, ax = plt.subplots(figsize=(12,5))
Q = ax.quiver(X, Y, U, V, pivot='mid', width=0.004)

plt.plot(x,g(x))
plt.tight_layout()
plt.grid()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in true_divide
#   import sys

# %%
def g(y):
  crecimiento = (np.exp(-y))*np.sin(y)
  return crecimiento

y_0 =np.linspace(-4,4,41)
h=0.01
t_0=0
t_N=20
plt.figure(figsize=(15,6))
for y in y_0 :
  t_list,y_list=euler(h,g,y, t_0,t_N)
  plt.plot(t_list,y_list)
plt.tight_layout()
plt.grid()

# %% [markdown]
# #2.2.5 $$\dot{x}=1+\frac{1}{2}cos(x) $$

# %%
def g(y):
  crecimiento = 1+1/2*np.cos(y)
  return crecimiento

x=np.linspace(-2*np.pi,2*np.pi,42)
X, Y = np.meshgrid(np.linspace(-2*np.pi,2*np.pi,12), 0)
U = g(X)/abs(g(X))
V = 0
fig, ax = plt.subplots(figsize=(12,5))
Q = ax.quiver(X, Y, U, V, pivot='mid', width=0.004)

plt.plot(x,g(x))
plt.tight_layout()
plt.grid()

# %%
def g(y):
  crecimiento = 1+1/2*np.cos(y)
  return crecimiento

y_0 =np.linspace(-2*np.pi,2*np.pi,22)
h=0.01
t_0=0
t_N=20
plt.figure(figsize=(15,6))
for y in y_0 :
  t_list,y_list=euler(h,g,y, t_0,t_N)
  plt.plot(t_list,y_list)
plt.tight_layout()
plt.grid()

# %% [markdown]
# #2.2.6 $$\dot{x}=1-2cos(x) $$

# %%
def g(y):
  crecimiento = 1-2*np.cos(y)
  return crecimiento

x=np.linspace(-2*np.pi,2*np.pi,42)
X, Y = np.meshgrid(np.linspace(-2*np.pi,2*np.pi,16), 0)
U = g(X)/abs(g(X))
V = 0
fig, ax = plt.subplots(figsize=(12,5))
Q = ax.quiver(X, Y, U, V, pivot='mid', width=0.004)

plt.plot(x,g(x))
plt.tight_layout()
plt.grid()

# %%
def g(y):
  crecimiento = 1-2*np.cos(y)
  return crecimiento

y_0 =np.linspace(-2*np.pi,2*np.pi,22)
h=0.01
t_0=0
t_N=3
plt.figure(figsize=(15,6))
for y in y_0 :
  t_list,y_list=euler(h,g,y, t_0,t_N)
  plt.plot(t_list,y_list)
plt.tight_layout()
plt.grid()

# %% [markdown]
# #2.2.7 $$\dot{x}=e^{x}-cos(x) $$
#
# (Hint: Sketch the graphs of $$e^x$$ and cos x on the same axes, and look for intersections. You won’t be able to find the fixed points explicitly, but you can still find the qualitative behavior.)

# %%
def g(y):
  crecimiento = np.exp(y)-np.cos(y)
  return crecimiento

x=np.linspace(-10,4,41)
X, Y = np.meshgrid(np.linspace(-10,4,15), 0)
U = g(X)/abs(g(X))
V = 0
fig, ax = plt.subplots(figsize=(12,5))
Q = ax.quiver(X, Y, U, V, pivot='mid', width=0.004)

plt.plot(x,g(x))
plt.tight_layout()
plt.grid()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in true_divide
#   import sys

# %%
def g(y):
  crecimiento = np.exp(y)-np.cos(y)
  return crecimiento

y_0 =np.linspace(-2*np.pi,2*np.pi,22)
h=0.01
t_0=0
t_N=3
plt.figure(figsize=(15,6))
for y in y_0 :
  t_list,y_list=euler(h,g,y, t_0,t_N)
  plt.plot(t_list,y_list)
plt.axis([t_0,t_N,-2*np.pi,2*np.pi])
plt.tight_layout()
plt.grid()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in exp
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in cos
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in exp
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in cos
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in exp
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in cos
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in exp
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in cos
#
# ...

# %% [markdown]
# 2.2.8 (Working backwards, from flows to equations) Given an equation
# x f   ( ) x , we know how to sketch the corresponding flow on the real line. Here you are asked to solve the opposite problem: For the phase portrait shown in Figure 1, find an equation that is consistent with it. (There are an infinite number of correct answers—and wrong ones too.)

# %%
def g(y):
  crecimiento =  y**4-3*y**2-2*y
  return crecimiento

x=np.linspace(-2,3,41)
X, Y = np.meshgrid(np.linspace(-2,3,15), 0)
U = g(X)/abs(g(X))
V = 0
fig, ax = plt.subplots(figsize=(12,5))
Q = ax.quiver(X, Y, U, V, width=0.004)

plt.plot(x,g(x))
plt.tight_layout()
plt.grid()

# %%
def g(y):
  crecimiento = y**4-3*y**2-2*y
  return crecimiento

y_0 = np.linspace(-2,3,41)
h=0.01
t_0=0
t_N=3
plt.figure(figsize=(15,6))
for y in y_0 :
  t_list,y_list=euler(h,g,y, t_0,t_N)
  plt.plot(t_list,y_list)
plt.axis([t_0,t_N,-2,3])
plt.tight_layout()
plt.grid()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in double_scalars
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in double_scalars
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in double_scalars
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in double_scalars
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in double_scalars
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in double_scalars
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in double_scalars
#
# ...

# %% [markdown]
# 2.2.9 (Backwards again, now from solutions to equations) Find an equation
# x f   ( ) x whose solutions x ( t) are consistent with those shown in Figure 2.

# %%
def g(y):
  crecimiento =  y**2-y
  return crecimiento

x=np.linspace(-1,2,21)
X, Y = np.meshgrid(np.linspace(-1,2,15), 0)
U = g(X)/abs(g(X))
V = 0
fig, ax = plt.subplots(figsize=(12,5))
Q = ax.quiver(X, Y, U, V, pivot='mid', width=0.004)

plt.plot(x,g(x))
plt.tight_layout()
plt.grid()

# %%
y_0 = x
h=0.01
t_0=0
t_N=3
plt.figure(figsize=(15,6))
for y in y_0 :
  t_list,y_list=euler(h,g,y, t_0,t_N)
  plt.plot(t_list,y_list)
plt.axis([t_0,t_N,-1,2])
plt.tight_layout()
plt.grid()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in double_scalars
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in double_scalars
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in double_scalars
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in double_scalars
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in double_scalars
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in double_scalars
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in double_scalars
#
# ...

# %% [markdown]
# 2.2.10 (Fixed points) For each of (a)–(e), find an equation x f   ( ) x with the
# stated properties, or if there are no examples, explain why not. (In all cases, assume that f ( x ) is a smooth function.)
#
# a) Every real number is a fixed point.
#
# b) Every integer is a fixed point, and there are no others.
#
# c) There are precisely three fixed points, and all of them are stable.
#
# d) There are no fixed points.
#
# e) There are precisely 100 fixed points.

# %% [markdown]
# 2.2.11 (Analytical solution for charging capacitor) Obtain the analytical solu
# tion of the initial value problem $$\dot{Q}=\frac{Vo}{R}-\frac{Q}{RC}$$, with Q(0)=0.

# %%
def g(y):
  crecimiento =  (20/100)-(y/(100*0.0047))
  return crecimiento


x=np.linspace(-0.2,0.4,15)
X, Y = np.meshgrid(np.linspace(-0.2,0.4,6), 0)
U = g(X)/abs(g(X))
V = 0
fig, ax = plt.subplots(figsize=(12,5))
Q = ax.quiver(X, Y, U, V, pivot='mid', width=0.004)

plt.plot(x,g(x))
plt.tight_layout()
plt.grid()

# %%
y_0 = 0
h=0.01
t_0=0
t_N=4
plt.figure(figsize=(15,6))
t_list,y_list=euler(h,g,y_0, t_0,t_N)
plt.plot(t_list,y_list)
plt.axis([t_0,t_N,-0.01,0.11])
plt.tight_layout()
plt.grid()

# %% [markdown]
# 2.2.12 (A nonlinear resistor) Suppose the
# resistor in Example 2.2.2 is replaced by a nonlinear resistor. In other words, this resistor does not have a linear relation between voltage and current. Such nonlinearity arises in certain solid-state devices.
# Instead of IR  V / R, suppose we have IR  g ( V ),where g ( V ) has the shape shown in Figure 3.
#
# Redo Example 2.2.2 in this case. Derive the circuit equations, find all the fixed points, and analyze their stability. What qualitative effects does the nonlinearity introduce (if any)?

# %% [markdown]
# 2.2.13 (Terminal velocity) The velocity v ( t ) of a skydiver falling to the ground is governed by mv mg kv  = − 2, where m is the mass of the skydiver, g is the acceleration due to gravity, and k > 0 is a constant related to the amount of air resistance.
#
# a) Obtain the analytical solution for v ( t ), assuming that v (0)  0.
# b) Find the limit of v ( t ) as t l d. This limiting velocity is called the terminal
# velocity. (Beware of bad jokes about the word terminal and parachutes that fail
# to open.)
# c) Give a graphical analysis of this problem, and thereby re-derive a formula for
# the terminal velocity.
# d) An experimental study (Carlson et al. 1942) confirmed that the equation
# mv mg kv  = − 2 gives a good quantitative fit to data on human skydivers. Six
# men were dropped from altitudes varying from 10,600 feet to 31,400 feet to a
# terminal altitude of 2,100 feet, at which they opened their parachutes. The long
# free fall from 31,400 to 2,100 feet took 116 seconds. The average weight of the
# men and their equipment was 261.2 pounds. In these units, g  32.2 ft / sec2
# .
#
# Compute the average velocity Vavg .
# e) Using the data given here, estimate the terminal velocity, and the value of the
# drag constant k. (Hints: First you need to find an exact formula for s ( t ), the
# distance fallen, where s (0)  0, s v   , and v ( t ) is known from part (a). You
# should get s t V
# g
# gt
# V ( ) ln cosh , = ( ) 2
#
# where V is the terminal velocity. Then solve
# for V graphically or numerically, using s  29,300, t  116, and g  32.2.)
#
# A slicker way to estimate V is to suppose V x Vavg, as a rough first approxi-
# mation. Then show that gt / V x 15. Since gt / V >> 1, we may use the approxima-
# tion ln(cosh x ) x x – ln 2 for x >> 1. Derive this approximation and then use it
#
# to obtain an analytical estimate of V. Then k follows from part (b). This analysis
# is from Davis (1962).

# %% [markdown]
# #2.4 Linear Stability Analysis
#
# Use linear stability analysis to classify the fixed points of the following systems.
# If linear stability analysis fails because f′(x*) = 0, use a graphical argument to decide the stability.

# %% [markdown]
# #2.4.1 $$\dot{x}=x(1-x) $$

# %%
def g(y):
  crecimiento = y*(1-y)
  return crecimiento

x=np.linspace(-1,2,41)
X, Y = np.meshgrid(np.linspace(-1,2,15), 0)
U = g(X)/abs(g(X))
V = 0
fig, ax = plt.subplots(figsize=(12,5))
Q = ax.quiver(X, Y, U, V, pivot='mid', width=0.004)

plt.plot(x,g(x))
plt.tight_layout()
plt.grid()

# %%
def g(y):
  crecimiento = y*(1-y)
  return crecimiento

y_0 = np.linspace(-1,2,41)
h=0.01
t_0=0
t_N=3
plt.figure(figsize=(15,6))
for y in y_0 :
  t_list,y_list=euler(h,g,y, t_0,t_N)
  plt.plot(t_list,y_list)
plt.axis([t_0,t_N,-1,2])
plt.tight_layout()
plt.grid()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in double_scalars
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in double_scalars
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in double_scalars
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in double_scalars
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in double_scalars
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in double_scalars
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in double_scalars
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in double_scalars
#
# ...

# %% [markdown]
# #2.4.2 $$\dot{x}=x(1-x)(2-x) $$

# %%
def g(y):
  crecimiento = y*(1-y)*(2-y)
  return crecimiento

x=np.linspace(-1,3,41)
X, Y = np.meshgrid(np.linspace(-1,3,15), 0)
U = g(X)/abs(g(X))
V = 0
fig, ax = plt.subplots(figsize=(12,5))
Q = ax.quiver(X, Y, U, V, pivot='mid', width=0.004)

plt.plot(x,g(x))
plt.tight_layout()
plt.grid()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in true_divide
#   import sys

# %%
def g(y):
  crecimiento = y*(1-y)*(2-y)
  return crecimiento

y_0 = np.linspace(-1,3,41)
h=0.01
t_0=0
t_N=3
plt.figure(figsize=(15,6))
for y in y_0 :
  t_list,y_list=euler(h,g,y, t_0,t_N)
  plt.plot(t_list,y_list)
plt.axis([t_0,t_N,-1,2])
plt.tight_layout()
plt.grid()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in double_scalars
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in double_scalars
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in double_scalars
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in double_scalars
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in double_scalars
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in double_scalars
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in double_scalars
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in double_scalars
#
# ...

# %% [markdown]
# #2.4.3 $$\dot{x}=tan(x) $$

# %%
def g(y):
  crecimiento = np.tan(y)
  return crecimiento

x=np.linspace(-2*np.pi,2*np.pi,23)
X, Y = np.meshgrid(np.linspace(-2*np.pi,2*np.pi,22), 0)
U = g(X)/abs(g(X))
V = 0
fig, ax = plt.subplots(figsize=(12,5))
Q = ax.quiver(X, Y, U, V, pivot='mid', width=0.004)

plt.plot(x,g(x))
plt.tight_layout()
plt.grid()

# %%
y_0 = x
h=0.01
t_0=0
t_N=3
plt.figure(figsize=(15,6))
for y in y_0 :
  t_list,y_list=euler(h,g,y, t_0,t_N)
  plt.plot(t_list,y_list)
plt.axis([t_0,t_N,-2*np.pi,2*np.pi])
plt.tight_layout()
plt.grid()

# %% [markdown]
# #2.4.4 $$\dot{x}= x^2(6-x)$$

# %%
def g(y):
  crecimiento = y**(2)*(6-y)
  return crecimiento

x=np.linspace(-1,7,23)
X, Y = np.meshgrid(np.linspace(-1,7,13), 0)
U = g(X)/abs(g(X))
V = 0
fig, ax = plt.subplots(figsize=(12,5))
Q = ax.quiver(X, Y, U, V, pivot='mid', width=0.004)

plt.plot(x,g(x))
plt.tight_layout()
plt.grid()

# %%
y_0 = x
h=0.01
t_0=0
t_N=3
plt.figure(figsize=(15,6))
for y in y_0 :
  t_list,y_list=euler(h,g,y, t_0,t_N)
  plt.plot(t_list,y_list)
plt.axis([t_0,t_N,-1,7])
plt.tight_layout()
plt.grid()

# %% [markdown]
# #2.4.5 $$\dot{x}=1 -e^{-x^{2}}$$

# %%
def g(y):
  crecimiento = 1 - np.exp(-y**2)
  return crecimiento

x=np.linspace(-3,3,23)
X, Y = np.meshgrid(np.linspace(-3,3,13), 0)
U = g(X)/abs(g(X))
V = 0
fig, ax = plt.subplots(figsize=(12,5))
Q = ax.quiver(X, Y, U, V, pivot='mid', width=0.004)

plt.plot(x,g(x))
plt.tight_layout()
plt.grid()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in true_divide
#   import sys

# %%
y_0 = x
h=0.01
t_0=0
t_N=3
plt.figure(figsize=(15,6))
for y in y_0 :
  t_list,y_list=euler(h,g,y, t_0,t_N)
  plt.plot(t_list,y_list)
plt.axis([t_0,t_N,-3,3])
plt.tight_layout()
plt.grid()

# %% [markdown]
# #2.4.6 $$\dot{x}=ln{x}$$

# %%
def g(y):
  crecimiento = np.log(y)
  return crecimiento

x=np.linspace(1,3,23)
X, Y = np.meshgrid(np.linspace(1,3,13), 0)
U = g(X)/abs(g(X))
V = 0
fig, ax = plt.subplots(figsize=(12,5))
Q = ax.quiver(X, Y, U, V, pivot='mid', width=0.004)

plt.plot(x,g(x))
plt.tight_layout()
plt.grid()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in true_divide
#   import sys

# %%
y_0 = x
h=0.01
t_0=0
t_N=3
plt.figure(figsize=(15,6))
for y in y_0 :
  t_list,y_list=euler(h,g,y, t_0,t_N)
  plt.plot(t_list,y_list)
plt.axis([t_0,t_N,1,3])
plt.tight_layout()
plt.grid()

# %% [markdown]
# #2.4.7 $$\dot{x}= ax-x^{3}$$
# Where a can be positive, negative, or zero. Discuss all three cases.

# %%
a_v=[-5,0,5]
for a in a_v:
  print(a)
  def g(y):
    crecimiento = a*y-y**3
    return crecimiento

  x=np.linspace(-3,3,23)
  X, Y = np.meshgrid(np.linspace(-3,3,13), 0)
  U = g(X)/abs(g(X))
  V = 0
  fig, ax = plt.subplots(figsize=(12,5))
  Q = ax.quiver(X, Y, U, V, pivot='mid', width=0.004)

  plt.plot(x,g(x))
  plt.tight_layout()
  plt.grid()
  plt.show()
  y_0 = x
  h=0.01
  t_0=0
  t_N=3
  plt.figure(figsize=(15,6))
  for y in y_0 :
    t_list,y_list=euler(h,g,y, t_0,t_N)
    plt.plot(t_list,y_list)
  plt.axis([t_0,t_N,-3,3])
  plt.tight_layout()
  plt.grid()
  plt.show()
# Out:
# -5
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: RuntimeWarning: invalid value encountered in true_divide
#   # Remove the CWD from sys.path while we load stuff.
# 0
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: RuntimeWarning: invalid value encountered in true_divide
#   # Remove the CWD from sys.path while we load stuff.
# 5
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: RuntimeWarning: invalid value encountered in true_divide
#   # Remove the CWD from sys.path while we load stuff.

# %% [markdown]
# #2.4.8
# Using linear stability analysis, classify the fixed points of the Gompertz model of tumor growth N aN  = − ln( ) bN . (As in Exercise 2.3.3, N ( t ) is proportional to the number of cells in the tumor and a,b  0 are parameters.)

# %% [markdown]
# 2.4.9 (Critical slowing down) In statistical mechanics, the phenomenon o“critical slowing down” is a signature of a second-order phase transition. At the transition, the system relaxes to equilibrium much more slowly than usual. Here’s a mathematical version of the effect:
#
# a) Obtain the analytical solution to x x  = − 3 for an arbitrary initial condition.
# Show that x t( ) l 0 as t l d but that the decay is not exponential. ( You should find that the decay is a much slower algebraic function of t.)
#
# b) To get some intuition about the slowness of the decay, make a numerically accurate plot of the solution for the initial condition x0  10, for 0 b t b 10. Then, on the same graph, plot the solution to x x  = − for the same initial condition.

# %% [markdown]
# 2.8 Solving Equations on the Computer
# 2.8.1 (Slope field) The slope is constant along horizontal lines in Figure 2.8.2.
# Why should we have expected this?
#
# 2.8.2 Sketch the slope field for the following differential equations. Then “inte-
# grate” the equation manually by drawing trajectories that are everywhere parallel
#
# to the local slope.
# a) x x   b) x x  = −1 2 c) x x  = −1 4 ( ) 1−x d) x x   sin
# 2.8.3 (Calibrating the Euler method) The goal of this problem is to test the
# Euler method on the initial value problem x x  = − , x (0)  1.
# a) Solve the problem analytically. What is the exact value of x (1)?
# b) Using the Euler method with step size %t  1, estimate x (1) numerically—call
# the result xˆ( )1 . Then repeat, using %t  10–n
#
# , for n  1, 2, 3, 4.
#
# c) Plot the error Ex x = − ˆ( )1 1( ) as a function of %t. Then plot ln E vs. ln t.
# Explain the results.
# 2.8.4 Redo Exercise 2.8.3, using the improved Euler method.
# 2.8.5 Redo Exercise 2.8.3, using the Runge–Kutta method.
# 2.8.6 (Analytically intractable problem) Consider the initial value problem
# x x  e x x =+ = − , () 00 . In contrast to Exercise 2.8.3, this problem can’t be solved
# analytically.
# a) Sketch the solution x ( t ) for t p 0.
# b) Using some analytical arguments, obtain rigorous bounds on the value of x at
# t  1. In other words, prove that a  x (1)  b, for a, b to be determined. By being
# clever, try to make a and b as close together as possible. (Hint: Bound the given
# vector field by approximate vector fields that can be integrated analytically.)
#
# Strogatz-CROPPED2.pdf 57 5/23/2014 8:40:06 AM
#
# 44 FLOWS ON THE LINE
#
# c) Now for the numerical part: Using the Euler method, compute x at t  1, cor-
# rect to three decimal places. How small does the stepsize need to be to obtain
#
# the desired accuracy? (Give the order of magnitude, not the exact number.)
# d) Repeat part (b), now using the Runge–Kutta method. Compare the results for
# stepsizes %t  1, %t  0.1, and %t  0.01.
# 2.8.7 (Error estimate for Euler method) In this question you’ll use Taylor series
# expansions to estimate the error in taking one step by the Euler method. The
# exact solution and the Euler approximation both start at x  x0 when t  t0. We
# want to compare the exact value x ( t1) w x ( t0
#
# %t ) with the Euler approximation
#
# x x fx t 10 0 = + ( )Δ .
# a) Expand x ( t1)  x ( t0
#
# %t ) as a Taylor series in %t, through terms of O ( %t 2
# ).
# Express your answer solely in terms of x0, %t, and f and its derivatives at x0.
# b) Show that the local error xt x ( ) 1 1  _ C ( %t )2 and give an explicit expression
# for the constant C. (Generally one is more interested in the global error incurred after integrating over a time interval of fixed length T  n%t. Since each step produces an O ( %t )2 error, and we take n  T / %t  O ( %t –1) steps, the global error xt x n n ( ) is O ( %t ), as claimed in the text.)
#
# 2.8.8 (Error estimate for the improved Euler method) Use the Taylor series
# arguments of Exercise 2.8.7 to show that the local error for the improved Euler
# method is O ( %t 3
# ).
#
# 2.8.9 (Error estimate for Runge–Kutta) Show that the Runge–Kutta method
# produces a local error of size O ( %t 5). (Warning: This calculation involves massive amounts of algebra, but if you do it correctly, you’ll be rewarded by seeing many wonderful cancellations. Teach yourself Mathematica, Maple, or some other symbolic manipulation language, and do the problem on the computer.)
